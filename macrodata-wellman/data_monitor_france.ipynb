# %% [markdown]
# ## French data monitor

# %% [markdown]
# Uses Eurostat database. Access directly and cross check via [here](https://ec.europa.eu/eurostat/data/database)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm # HP filter and OLS regression
import datetime

# %%
import eurostat
import data_monitor_eurostat_load as estatload

# %%
plt.rcParams['figure.figsize'] = [16, 8]
plt.rcParams['font.size'] = 22
plt.rcParams['lines.linewidth'] = 2.5

# %%
pd.set_option('display.precision', 2)

# %% [markdown]
# ### How to get data series on particular theme

# %% [markdown]
# Get table of contents, narrow it down based on keywords

# %%
toc = eurostat.get_toc_df()

# %%
eurostat.subset_toc_df(toc, "labour productivity")
# Out:
#                                                   title             code  \
# 949   Labour productivity in GDP (constant prices) p...  enpe_nama_10_lp
# 1259          Labour productivity and unit labour costs   nama_10_lp_ulc
# 1260  Labour productivity and unit labour costs at i...   nama_10_lp_a21
# 1262              Labour Productivity at regional level      nama_10r_lp
# 1263      Nominal Labour productivity by NUTS 2 regions    nama_10r_2nlp
# 1264      Nominal Labour productivity by NUTS 3 regions    nama_10r_3nlp
# 1265         Real Labour productivity by NUTS 2 regions    nama_10r_2rlp
# 1275          Labour productivity and unit labour costs   namq_10_lp_ulc
# 8116  Nominal labour productivity per person employe...         tec00116
# 8599        Apparent labour productivity by NACE Rev. 2         tin00152
# 8600   Wage adjusted labour productivity by NACE Rev. 2         tin00153
# 9137  Real labour productivity per person employed -...         tipsna70
# 9143  Real labour productivity per person employed -...         tipsna71
# 9616  Labour productivity per person employed and ho...         tesem160
#
#          type last update of data last table structure change data start  \
# 949   dataset          11.02.2022                  26.01.2022       2005
# 1259  dataset          02.12.2022                  14.01.2022       1975
# 1260  dataset          03.12.2022                  14.01.2022       1975
# 1262   folder
# 1263  dataset          06.05.2022                  20.02.2022       2000
# 1264  dataset          06.05.2022                  20.02.2022       2000
# 1265  dataset          06.05.2022                  20.02.2022       1995
# 1275  dataset          02.12.2022                  27.10.2022     1975Q1
# 8116    table          02.12.2022                  02.12.2022       2010
# 8599    table          27.10.2022                  27.10.2022       2009
# 8600    table          27.10.2022                  27.10.2022       2009
# 9137    table          02.12.2022                  02.12.2022       1995
# 9143    table          02.12.2022                  02.12.2022     1995Q1
# 9616    table          02.12.2022                  02.12.2022       2005
#
#      data end
# 949      2020
# 1259     2021
# 1260     2021
# 1262
# 1263     2020
# 1264     2020
# 1265     2020
# 1275   2022Q3
# 8116     2021
# 8599     2020
# 8600     2020
# 9137     2021
# 9143   2022Q3
# 9616     2021

# %% [markdown]
# Once `code` is known, extract that table

# %%
unemp_fr = estatload.get_eurostat_country_data('ei_lmhr_m', 'FR', 'SA')

# %%
unemp_countries = estatload.get_eurostat_allcountry_data('ei_lmhr_m', 'LM-UN-T-TOT', 'SA')

# %%
#Another series of interest may be TOT_X_NRG_FOOD_S, ie core inflation

# %%
hicp_countries = estatload.get_eurostat_allcountry_hicp('prc_hicp_midx', 'CP00')

# %% [markdown]
# ### Get productivity

# %%
df = eurostat.get_data_df('namq_10_lp_ulc', flags=False)

# %% [markdown]
# See flags available

# %%
df[(df['geo\\time']=='FR')]
# Out:
#             unit s_adj   na_item geo\time  2022Q3  2022Q2  2022Q1  2021Q4  \
# 16   CLV_PCH_PRE   SCA   RLPR_HW       FR     NaN     NaN     NaN     NaN
# 51   CLV_PCH_PRE   SCA  RLPR_PER       FR     NaN     NaN     NaN     NaN
# 84    CLV_PCH_SM   NSA   NULC_HW       FR     NaN     NaN     NaN     NaN
# 119   CLV_PCH_SM   NSA  NULC_PER       FR     NaN     NaN     NaN     NaN
# 152   CLV_PCH_SM   NSA   RLPR_HW       FR     NaN     NaN     NaN     NaN
# 188   CLV_PCH_SM   NSA  RLPR_PER       FR     NaN     NaN     NaN     NaN
# 222   CLV_PCH_SM   SCA   RLPR_HW       FR     NaN     NaN     NaN     NaN
# 257   CLV_PCH_SM   SCA  RLPR_PER       FR     NaN     NaN     NaN     NaN
# 290          I10   NSA   NULC_HW       FR  117.88  116.27  114.09  114.03
# 327          I10   NSA  NULC_PER       FR  119.16  117.52  115.33  115.20
# 363          I10   NSA   RLPR_HW       FR  102.21  104.96  106.03  107.79
# 401          I10   NSA  RLPR_PER       FR  100.68  103.18  103.39  106.60
# 438          I10   SCA   RLPR_HW       FR  104.89  105.07  105.78  105.76
# 476          I10   SCA  RLPR_PER       FR  103.17  103.41  103.27  103.95
# 512          I15   NSA   NULC_HW       FR  111.92  110.39  108.32  108.26
# 549          I15   NSA  NULC_PER       FR  112.92  111.37  109.30  109.17
# 585          I15   NSA   RLPR_HW       FR   97.77  100.40  101.43  103.11
# 623          I15   NSA  RLPR_PER       FR   97.60  100.02  100.23  103.34
# 661          I15   SCA   RLPR_HW       FR  100.74  100.90  101.58  101.57
# 699          I15   SCA  RLPR_PER       FR   99.89  100.12   99.99  100.65
# 735      PCH_PRE   SCA   RLPR_HW       FR   -0.20   -0.70    0.00   -0.50
# 772      PCH_PRE   SCA  RLPR_PER       FR   -0.20    0.10   -0.70   -0.20
# 808       PCH_SM   NSA   NULC_HW       FR    5.00    4.90    3.90    2.70
# 845       PCH_SM   NSA  NULC_PER       FR    5.10    4.80    3.70    2.60
# 881       PCH_SM   NSA   RLPR_HW       FR   -0.90   -2.20   -2.60   -3.90
# 919       PCH_SM   NSA  RLPR_PER       FR   -1.00    1.60    1.60    1.50
# 955       PCH_SM   SCA   RLPR_HW       FR   -1.30   -2.90   -2.80   -3.30
# 992       PCH_SM   SCA  RLPR_PER       FR   -0.90    1.40    1.60    1.90
#
#      2021Q3  2021Q2  ...  1977Q2  1977Q1  1976Q4  1976Q3  1976Q2  1976Q1  \
# 16      NaN   -0.10  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 51      NaN    0.70  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 84      NaN   -4.10  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 119     NaN   -4.00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 152     NaN   -1.80  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 188     NaN   16.90  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 222     NaN   -2.50  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 257     NaN   15.90  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 290  112.29  110.85  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 327  113.35  112.12  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 363  103.11  107.37  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 401  101.74  101.59  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 438  106.28  108.16  ...    52.0    51.6    50.7    50.2    49.8    49.5
# 476  104.14  101.93  ...    62.0    61.9    61.3    61.0    60.6    59.9
# 512  106.61  105.25  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 549  107.42  106.25  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 585   98.64  102.71  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 623   98.63   98.48  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 661  102.07  103.88  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 699  100.83   98.69  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 735   -1.70   -0.60  ...     0.9     1.8     0.8     0.8     0.6    -0.2
# 772    2.20    0.30  ...     0.1     0.9     0.4     0.8     1.1     0.6
# 808    1.90   -4.50  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 845    2.10   -4.30  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 881   -1.90   -3.00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 919    0.30   15.30  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 955   -1.20   -3.50  ...     4.3     4.1     2.1     2.6     1.7     1.3
# 992    0.50   14.40  ...     2.3     3.3     3.0     4.5     3.7     2.6
#
#      1975Q4  1975Q3  1975Q2  1975Q1
# 16      NaN     NaN     NaN     NaN
# 51      NaN     NaN     NaN     NaN
# 84      NaN     NaN     NaN     NaN
# 119     NaN     NaN     NaN     NaN
# 152     NaN     NaN     NaN     NaN
# 188     NaN     NaN     NaN     NaN
# 222     NaN     NaN     NaN     NaN
# 257     NaN     NaN     NaN     NaN
# 290     NaN     NaN     NaN     NaN
# 327     NaN     NaN     NaN     NaN
# 363     NaN     NaN     NaN     NaN
# 401     NaN     NaN     NaN     NaN
# 438    49.6    49.0    49.0    48.9
# 476    59.5    58.4    58.4    58.4
# 512     NaN     NaN     NaN     NaN
# 549     NaN     NaN     NaN     NaN
# 585     NaN     NaN     NaN     NaN
# 623     NaN     NaN     NaN     NaN
# 661     NaN     NaN     NaN     NaN
# 699     NaN     NaN     NaN     NaN
# 735     1.4    -0.1     0.2     0.3
# 772     1.9     0.1     0.0    -0.2
# 808     NaN     NaN     NaN     NaN
# 845     NaN     NaN     NaN     NaN
# 881     NaN     NaN     NaN     NaN
# 919     NaN     NaN     NaN     NaN
# 955     1.9    -0.5     1.0     1.9
# 992     1.7    -1.7    -0.8    -0.2
#
# [28 rows x 195 columns]

# %% [markdown]
# Productivity per person

# %%
prod_per_countries = df[(df['unit']=='I10') & (df['na_item']=='RLPR_PER') & (df['s_adj']=='SCA')].drop(['unit', 'na_item', 's_adj'],axis=1).set_index('geo\\time').T
prod_per_countries = prod_per_countries.set_index(pd.to_datetime(prod_per_countries.index)).sort_index()
prod_per_countries.index.name='date'

# %% [markdown]
# Productivity per hour worked

# %%
prod_hw_countries = df[(df['unit']=='I10') & (df['na_item']=='RLPR_HW') & (df['s_adj']=='SCA')].drop(['unit', 'na_item', 's_adj'],axis=1).set_index('geo\\time').T
prod_hw_countries = prod_hw_countries.set_index(pd.to_datetime(prod_hw_countries.index)).sort_index()
prod_hw_countries.index.name='date'

# %% [markdown]
# ### Quick look at the latest data

# %%
def get_latest_series(ser, name):
    # Extract latest available datapoint from a series
    # Store latest date and value, index using 'name'
    latest = ser[ser.notnull()].tail(1)
    latest= pd.DataFrame(latest).assign(name=name).reset_index().set_index('name')
    latest.columns = ['date_latest', 'value_latest']
    pre_latest = ser[ser.notnull()].tail(2).head(1)
    pre_latest= pd.DataFrame(pre_latest).assign(name=name).reset_index().set_index('name')
    pre_latest.columns = ['date_previous', 'value_previous']
    pre_latest.drop(['date_previous'], axis=1, inplace=True)
    return latest.join(pre_latest)

def plot_latest(servals, sernames):
    # show table with latest variables in servals, with names in sernames
    latest = sernames # Declare a list with same names
    for i, sername in enumerate(sernames):
        latest[i]=get_latest_series(servals[i], sername)
    display(pd.concat(latest))

# %%
servals   = [unemp_fr['LM-UN-T-TOT'], unemp_fr['LM-UN-T-LE25']]
sernames  = ['Unemployment rate (all)', 'Youth unemployment(<=25)']

plot_latest(servals, sernames)
# Out:
#                          date_latest  value_latest  value_previous
# name
# Unemployment rate (all)   2022-10-01           7.1             7.1
# Youth unemployment(<=25)  2022-10-01          18.2            17.8

# %%
servals   = [unemp_countries['US'], unemp_countries['EA19'], unemp_countries['FR'], unemp_countries['DE']]
sernames  = ['Unemployment rate US', 'Unemployment rate EA19',  'Unemployment rate France',  'Unemployment rate Germany']

plot_latest(servals, sernames)
# Out:
#                           date_latest  value_latest  value_previous
# name
# Unemployment rate US       2022-10-01           3.7             3.5
# Unemployment rate EA19     2022-10-01           6.5             6.6
# Unemployment rate France   2022-10-01           7.1             7.1
# Unemployment rate Germany  2022-10-01           3.0             3.0

# %%
hicpinfl_fr = 100*(hicp_countries['FR']-hicp_countries['FR'].shift(12))/hicp_countries['FR'].shift(12)
hicpinfl_de = 100*(hicp_countries['DE']-hicp_countries['DE'].shift(12))/hicp_countries['DE'].shift(12)
hicpinfl_eu = 100*(hicp_countries['EA']-hicp_countries['EA'].shift(12))/hicp_countries['EA'].shift(12)

# %%
servals   = [hicpinfl_fr, hicpinfl_de,hicpinfl_eu]
sernames  = ['HICP inflation France', 'HICP inflation Germany',  'HICP inflation EA']

plot_latest(servals, sernames)
# Out:
#                        date_latest  value_latest  value_previous
# name
# HICP inflation France   2022-11-01          7.13            7.07
# HICP inflation Germany  2022-10-01         11.56           10.90
# HICP inflation EA       2022-11-01         10.03           10.62

# %% [markdown]
# ### Plotting area

# %%
hicpinfl_fr.plot(label='France')
hicpinfl_de.plot(label='Germany')
hicpinfl_eu.plot(label='Euro Area')
#plt.xlim('2000-01-01', '2022-12-01')
plt.title('HICP inflation')
plt.legend()
plt.show()

# %%
unemp_fr['LM-UN-T-TOT'].plot(label='overall')
unemp_fr['LM-UN-T-LE25'].plot(label='youth')
#plt.xlim('2000-01-01', '2022-12-01')
plt.title('French unemployment')
plt.legend()
plt.show()

# %%
unemp_countries['DE'].plot(label='Germany')
unemp_countries['EA19'].plot(label='Euro Area 19')
unemp_countries['FR'].plot(label='France')
unemp_countries['US'].plot(label='US')
plt.legend()
plt.title('Unemployment rate by country')
# Out:
# Text(0.5, 1.0, 'Unemployment rate by country')

# %%
prod_per_countries
# Out:
# geo\time        AT      BE      BG      CH      CY      CZ      DE      DK  \
# date
# 1975-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1975-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1975-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1975-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1976-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07-01  103.27  104.29  130.46  106.41  108.06  116.00  105.71  109.44
# 2021-10-01  101.57  104.51  132.17  105.90  109.72  116.92  105.33  110.86
# 2022-01-01  102.05  104.56  132.13  106.16  110.88  117.28  105.71  109.24
# 2022-04-01  103.65  104.52  132.89  106.09  110.54  115.95  105.54  109.67
# 2022-07-01  103.70  104.25  133.43  106.36  110.88  115.90  105.91  109.65
#
# geo\time        EA    EA12  ...      NL      NO      PL      PT      RO  \
# date                        ...
# 1975-01-01     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1975-04-01     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1975-07-01     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1975-10-01     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1976-01-01     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2021-07-01  105.17  104.56  ...  104.05  108.50  134.37  102.74  145.72
# 2021-10-01  104.98  104.48  ...  103.92  107.32  136.04  104.66  146.01
# 2022-01-01  104.97  104.54  ...  103.08  105.63  143.28  105.65  147.29
# 2022-04-01     NaN  105.07  ...  104.70  106.31  139.49  105.66  149.83
# 2022-07-01     NaN  105.05  ...  103.97  107.36  141.35  106.29  152.66
#
# geo\time        RS      SE      SI      SK  UK
# date
# 1975-01-01     NaN     NaN     NaN     NaN NaN
# 1975-04-01     NaN     NaN     NaN     NaN NaN
# 1975-07-01     NaN     NaN     NaN     NaN NaN
# 1975-10-01     NaN     NaN     NaN     NaN NaN
# 1976-01-01     NaN     NaN     NaN     NaN NaN
# ...            ...     ...     ...     ...  ..
# 2021-07-01  109.25  109.70  112.78  114.87 NaN
# 2021-10-01  110.19  110.54  117.84  114.85 NaN
# 2022-01-01  111.81  109.48  116.97  114.68 NaN
# 2022-04-01  109.70  109.47  116.65  114.47 NaN
# 2022-07-01     NaN  109.60  114.74  114.76 NaN
#
# [191 rows x 38 columns]

# %%
prod_per_countries['DE'].plot(label='Germany')
prod_per_countries['EA19'].plot(label='Euro Area 19')
prod_per_countries['FR'].plot(label='France')
prod_per_countries['UK'].plot(label='UK')
plt.legend()
# Zoom in on relevant time period
plt.xlim('1995-01-01', '2019-01-01')
plt.ylim(80,110)
plt.title('Labor productivity per person');

# %%
prod_hw_countries['DE'].plot(label='Germany')
prod_hw_countries['EA19'].plot(label='Euro Area 19')
prod_hw_countries['FR'].plot(label='France')
prod_hw_countries['UK'].plot(label='UK')
plt.legend()
# Zoom in on relevant time period
plt.xlim('1995-01-01', '2019-01-01')
plt.ylim(70,110)
plt.title('Labor productivity per hour worked');
